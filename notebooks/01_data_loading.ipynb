# %%
import pandas as pd

# %%
url = "https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=5"
df=pd.read_json(url)
df.head()
# Out:
#    unique_key             created_date agency  \
# 0    66460470  2025-10-13T01:51:20.000   NYPD
# 1    66460469  2025-10-13T01:51:10.000   NYPD
# 2    66459255  2025-10-13T01:50:58.000   NYPD
# 3    66454647  2025-10-13T01:50:58.000   NYPD
# 4    66454648  2025-10-13T01:50:48.000   NYPD
#
#                        agency_name           complaint_type        descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 2  New York City Police Department      Urinating in Public               N/A
# 3  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 4  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#                 location_type  incident_zip     incident_address  \
# 0             Street/Sidewalk         11368     100-26 41 AVENUE
# 1             Street/Sidewalk         11368     102-03 41 AVENUE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      5 non-null      int64
#  1   created_date                    5 non-null      object
#  2   agency                          5 non-null      object
#  3   agency_name                     5 non-null      object
#  4   complaint_type                  5 non-null      object
#  5   descriptor                      5 non-null      object
#  6   location_type                   5 non-null      object
#  7   incident_zip                    5 non-null      int64
#  8   incident_address                5 non-null      object
#  9   street_name                     5 non-null      object
#  10  cross_street_1                  5 non-null      object
#  11  cross_street_2                  5 non-null      object
# ...

# %%
df.columns
# Out:
# Index(['unique_key', 'created_date', 'agency', 'agency_name', 'complaint_type',
#        'descriptor', 'location_type', 'incident_zip', 'incident_address',
#        'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'status', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location', ':@computed_region_efsh_h5xi',
#        ':@computed_region_f5dn_yrer', ':@computed_region_yeji_bk3q',
#        ':@computed_region_92fq_4b7q', ':@computed_region_sbqj_enih',
#        ':@computed_region_7mpf_4k6g', 'resolution_action_updated_date'],
#       dtype='object')
